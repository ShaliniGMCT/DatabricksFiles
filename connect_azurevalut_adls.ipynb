# %%
service_credential = dbutils.secrets.get(scope="dbsecretscope",key="kvsecret")

spark.conf.set("fs.azure.account.auth.type.dbstorageaccountshalini.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.dbstorageaccountshalini.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.dbstorageaccountshalini.dfs.core.windows.net", "2aabb69d-9e71-43f1-a9a8-9e33451e7fff")
spark.conf.set("fs.azure.account.oauth2.client.secret.dbstorageaccountshalini.dfs.core.windows.net", service_credential)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.dbstorageaccountshalini.dfs.core.windows.net", "https://login.microsoftonline.com/f842e67e-1b74-4d29-bb9d-c50055f79386/oauth2/token")

# %%
dbutils.fs.ls("abfss://babydatacontainer@dbstorageaccountshalini.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://babydatacontainer@dbstorageaccountshalini.dfs.core.windows.net/Sales_Lead.csv', name='Sales_Lead.csv', size=98045, modificationTime=1762758110000)]

# %%
# %sql
CREATE TABLE IF NOT EXISTS dbworkspace.adventureworks.babynamedatatable;

COPY INTO dbworkspace.adventureworks.babynamedatatable
FROM 'abfss://babydatacontainer@dbstorageaccountshalini.dfs.core.windows.net/'
FILEFORMAT = CSV
COPY_OPTIONS ('mergeSchema' = 'true');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th><th>num_skipped_corrupt_files</th></tr></thead><tbody><tr><td>501</td><td>501</td><td>0</td></tr></tbody></table></div>
