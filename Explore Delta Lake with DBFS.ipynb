# %%
dbutils.fs.mkdirs("dbfs:/delta_lab")
#urls = [("products.csv", "https://raw.githubusercontent.com/MicrosoftLearning/mslearn-databricks/main/data/products.csv")]
dbutils.fs.cp("https://raw.githubusercontent.com/MicrosoftLearning/mslearn-databricks/main/data/products.csv", f"dbfs:/delta_lab/products.csv")
# Out:
# True

# %%
df = spark.read.load('/delta_lab/products.csv', format='csv', header=True)
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductID</th><th>ProductName</th><th>Category</th><th>ListPrice</th></tr></thead><tbody><tr><td>771</td><td>Mountain-100 Silver, 38</td><td>Mountain Bikes</td><td>3399.9900</td></tr><tr><td>772</td><td>Mountain-100 Silver, 42</td><td>Mountain Bikes</td><td>3399.9900</td></tr><tr><td>773</td><td>Mountain-100 Silver, 44</td><td>Mountain Bikes</td><td>3399.9900</td></tr><tr><td>774</td><td>Mountain-100 Silver, 48</td><td>Mountain Bikes</td><td>3399.9900</td></tr><tr><td>775</td><td>Mountain-100 Black, 38</td><td>Mountain Bikes</td><td>3374.9900</td></tr><tr><td>776</td><td>Mountain-100 Black, 42</td><td>Mountain Bikes</td><td>3374.9900</td></tr><tr><td>777</td><td>Mountain-100 Black, 44</td><td>Mountain Bikes</td><td>3374.9900</td></tr><tr><td>778</td><td>Mountain-100 Black, 48</td><td>Mountain Bikes</td><td>3374.9900</td></tr><tr><td>779</td><td>Mountain-200 Silver, 38</td><td>Mountain Bikes</td><td>2319.9900</td></tr><tr><td>780</td><td>Mountain-200 Silver, 42</td><td>Mountain Bikes</td><td>2319.9900</td></tr></tbody></table></div>

# %%
delta_table_path = "/delta/products-delta"
df.write.mode("overwrite").format("delta").save(delta_table_path)

# %%
 # %sh
 ls /dbfs/delta/products-delta
# Out:
# _delta_log
# deletion_vector_95b137d6-daf6-4ea5-8b3f-e0e418e5121c.bin
# part-00000-6453a694-901e-4cc8-bf45-1ab245085795.c000.snappy.parquet
# part-00000-e711f44c-50c6-487c-8f55-490a1beb6c3f.c000.snappy.parquet
# part-00000-f1fae48f-c5e0-49fb-ba95-2e0a100c3efe.c000.snappy.parquet
# part-00000-f2cdb9c8-e162-45c4-bbac-e0444fe39406.c000.snappy.parquet

# %%
from delta.tables import *
from pyspark.sql.functions import *
   
# Create a deltaTable object
deltaTable = DeltaTable.forPath(spark, delta_table_path)
# Update the table (reduce price of product 771 by 10%)
deltaTable.update(
    condition = "ProductID == 771",
    set = { "ListPrice": "ListPrice * 0.9" })
# View the updated data as a dataframe
deltaTable.toDF().show(10)
# Out:
# +---------+--------------------+--------------+---------+
# |ProductID|         ProductName|      Category|ListPrice|
# +---------+--------------------+--------------+---------+
# |      772|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      773|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      774|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      775|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      776|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      777|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      778|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      779|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# |      780|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# |      781|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# +---------+--------------------+--------------+---------+
# only showing top 10 rows

# %%
new_df = spark.read.format("delta").load(delta_table_path)
new_df.show(10)
# Out:
# +---------+--------------------+--------------+---------+
# |ProductID|         ProductName|      Category|ListPrice|
# +---------+--------------------+--------------+---------+
# |      772|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      773|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      774|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      775|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      776|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      777|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      778|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      779|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# |      780|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# |      781|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# +---------+--------------------+--------------+---------+
# only showing top 10 rows

# %%
new_df = spark.read.format("delta").option("versionAsOf", 0).load(delta_table_path)
new_df.show(10)
# Out:
# +---------+--------------------+--------------+---------+
# |ProductID|         ProductName|      Category|ListPrice|
# +---------+--------------------+--------------+---------+
# |      771|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      772|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      773|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      774|Mountain-100 Silv...|Mountain Bikes|3399.9900|
# |      775|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      776|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      777|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      778|Mountain-100 Blac...|Mountain Bikes|3374.9900|
# |      779|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# |      780|Mountain-200 Silv...|Mountain Bikes|2319.9900|
# +---------+--------------------+--------------+---------+
# only showing top 10 rows

# %%
deltaTable.history(10).show(10, False, True)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 4
#  timestamp           | 2025-11-12 14:35:59
#  userId              | 8767521372405224
#  userName            | fabtrainer@shalinigupta2501outlook.onmicrosoft.com
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(cast(ProductID#593 as int) = 771)"]}
#  job                 | NULL
#  notebook            | {670448288738878}
#  clusterId           | 1104-063858-1vbc9wsf
#  readVersion         | 3
#  isolationLevel      | WriteSerializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 5455, numDeletionVectorsUpdated -> 0, scanTimeMs -> 2983, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 1393, rewriteTimeMs -> 2430}
#  userMetadata        | NULL
#  engineInfo          | Databricks-Runtime/16.4.x-cpu-ml-photon-scala2.12
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 3
#  timestamp           | 2025-11-12 14:34:56
#  userId              | 8767521372405224
#  userName            | fabtrainer@shalinigupta2501outlook.onmicrosoft.com
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, statsOnLoad -> false, partitionBy -> []}
#  job                 | NULL
#  notebook            | {670448288738878}
#  clusterId           | 1104-063858-1vbc9wsf
#  readVersion         | 2
#  isolationLevel      | WriteSerializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 2, numRemovedBytes -> 7670, numOutputRows -> 295, numOutputBytes -> 6277}
#  userMetadata        | NULL
#  engineInfo          | Databricks-Runtime/16.4.x-cpu-ml-photon-scala2.12
# -RECORD 2-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 2
#  timestamp           | 2025-11-11 07:13:59
#  userId              | 8767521372405224
#  userName            | fabtrainer@shalinigupta2501outlook.onmicrosoft.com
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(cast(ProductID#883 as int) = 771)"]}
#  job                 | NULL
#  notebook            | {670448288738878}
#  clusterId           | 1104-063858-1vbc9wsf
#  readVersion         | 1
#  isolationLevel      | WriteSerializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 4020, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1934, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 1393, rewriteTimeMs -> 2049}
#  userMetadata        | NULL
#  engineInfo          | Databricks-Runtime/16.4.x-cpu-ml-photon-scala2.12
# -RECORD 3-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 1
#  timestamp           | 2025-11-11 07:13:07
#  userId              | 8767521372405224
#  userName            | fabtrainer@shalinigupta2501outlook.onmicrosoft.com
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, statsOnLoad -> false, partitionBy -> []}
#  job                 | NULL
#  notebook            | {670448288738878}
#  clusterId           | 1104-063858-1vbc9wsf
#  readVersion         | 0
#  isolationLevel      | WriteSerializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 6277, numOutputRows -> 295, numOutputBytes -> 6277}
#  userMetadata        | NULL
#  engineInfo          | Databricks-Runtime/16.4.x-cpu-ml-photon-scala2.12
# -RECORD 4-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 0
#  timestamp           | 2025-11-09 09:04:39
#  userId              | 8767521372405224
#  userName            | fabtrainer@shalinigupta2501outlook.onmicrosoft.com
#  operation           | WRITE
#  operationParameters | {mode -> ErrorIfExists, statsOnLoad -> false, partitionBy -> []}
#  job                 | NULL
#  notebook            | {670448288738878}
#  clusterId           | 1104-063858-1vbc9wsf
#  readVersion         | NULL
#  isolationLevel      | WriteSerializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 1, numOutputRows -> 295, numOutputBytes -> 6277}
#  userMetadata        | NULL
#  engineInfo          | Databricks-Runtime/16.4.x-cpu-ml-photon-scala2.12

# %%
new_df.write.format("delta").mode("overwrite").saveAsTable("AdventureWorks.ProductsManaged")
spark.sql("DESCRIBE EXTENDED AdventureWorks.productsmanaged").show(truncate=False)
# Out:
# +----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |col_name                    |data_type                                                                                                                                                                                          |comment|
# +----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |ProductID                   |string                                                                                                                                                                                             |NULL   |
# |ProductName                 |string                                                                                                                                                                                             |NULL   |
# |Category                    |string                                                                                                                                                                                             |NULL   |
# |ListPrice                   |string                                                                                                                                                                                             |NULL   |
# |                            |                                                                                                                                                                                                   |       |
# |# Delta Statistics Columns  |                                                                                                                                                                                                   |       |
# |Column Names                |ProductID, ProductName, Category, ListPrice                                                                                                                                                        |       |
# |Column Selection Method     |first-32                                                                                                                                                                                           |       |
# |                            |                                                                                                                                                                                                   |       |
# |# Detailed Table Information|                                                                                                                                                                                                   |       |
# |Catalog                     |dbworkspace                                                                                                                                                                                        |       |
# |Database                    |AdventureWorks                                                                                                                                                                                     |       |
# |Table                       |productsmanaged                                                                                                                                                                                    |       |
# |Created Time                |Tue Nov 11 07:22:52 UTC 2025                                                                                                                                                                       |       |
# |Last Access                 |UNKNOWN                                                                                                                                                                                            |       |
# |Created By                  |Spark                                                                                                                                                                                              |       |
# |Statistics                  |4305 bytes, 295 rows                                                                                                                                                                               |       |
# |Type                        |MANAGED                                                                                                                                                                                            |       |
# |Location                    |abfss://unity-catalog-storage@dbstorager24d665cashdm.dfs.core.windows.net/4157253004294376/__unitystorage/catalogs/4d565a32-623b-4672-b05d-ef67d36410c6/tables/7692c995-9c3d-4bc3-8b17-40bf1cff7e85|       |
# |Provider                    |delta                                                                                                                                                                                              |       |
# +----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# only showing top 20 rows

# %%
# %sql
SELECT
  `Category`,
  AVG(CAST(`ListPrice` AS DOUBLE)) AS `AverageListPrice`
FROM
  `dbworkspace`.`adventureworks`.`productsmanaged`
GROUP BY
  `Category`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>AverageListPrice</th></tr></thead><tbody><tr><td>Headsets</td><td>87.07333333333334</td></tr><tr><td>Wheels</td><td>220.92928571428567</td></tr><tr><td>Bottom Brackets</td><td>92.24</td></tr><tr><td>Touring Frames</td><td>631.4155555555556</td></tr><tr><td>Mountain Bikes</td><td>1683.3649999999982</td></tr><tr><td>Pedals</td><td>64.01857142857143</td></tr><tr><td>Derailleurs</td><td>106.475</td></tr><tr><td>Chains</td><td>20.24</td></tr><tr><td>Pumps</td><td>22.49</td></tr><tr><td>Hydration Packs</td><td>54.99</td></tr><tr><td>Road Bikes</td><td>1597.4499999999994</td></tr><tr><td>Bottles and Cages</td><td>7.989999999999999</td></tr><tr><td>Road Frames</td><td>780.0436363636371</td></tr><tr><td>Forks</td><td>184.4</td></tr><tr><td>Vests</td><td>63.5</td></tr><tr><td>Brakes</td><td>106.5</td></tr><tr><td>Helmets</td><td>34.99</td></tr><tr><td>Saddles</td><td>39.63333333333333</td></tr><tr><td>Tights</td><td>74.99</td></tr><tr><td>Jerseys</td><td>51.99</td></tr><tr><td>Gloves</td><td>31.240000000000006</td></tr><tr><td>Panniers</td><td>125.0</td></tr><tr><td>Touring Bikes</td><td>1425.2481818181814</td></tr><tr><td>Bike Racks</td><td>120.0</td></tr><tr><td>Fenders</td><td>21.98</td></tr><tr><td>Caps</td><td>8.99</td></tr><tr><td>Lights</td><td>31.323333333333334</td></tr><tr><td>Cranksets</td><td>278.99</td></tr><tr><td>Shorts</td><td>64.27571428571429</td></tr><tr><td>Locks</td><td>25.0</td></tr><tr><td>Bike Stands</td><td>159.0</td></tr><tr><td>Bib-Shorts</td><td>89.99</td></tr><tr><td>Handlebars</td><td>73.89</td></tr><tr><td>Mountain Frames</td><td>678.2535714285716</td></tr><tr><td>Tires and Tubes</td><td>19.482727272727274</td></tr><tr><td>Cleaners</td><td>7.95</td></tr><tr><td>Socks</td><td>9.245000000000001</td></tr></tbody></table></div>
